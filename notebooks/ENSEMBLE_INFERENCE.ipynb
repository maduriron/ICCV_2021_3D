# %%
import os
import torch 
from models_scripts import i3_res50, i3_res50_nl, disable_bn, enable_bn
from utilities_scripts import SAM, LR_Scheduler, get_criterion, LoadingBar, Log, initialize, RandAugment
from dataset_scripts import CTDataset, CTDatasetTestSimple
import json

from torch.utils.data import DataLoader
import torchvision

batch_size = 1
cuda_device_index = 0
n_class = 2 # extend number of classes
root = "/home/sentic/storage2/iccv_test_madu"
num_workers = 2 # workers for dataloader
fold_test_path = "./test_set_folding.json"
fold_id = "1"
model_paths = [
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold1_extended/checkpoint_model8E_60_1_43.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold1_1/checkpoint_model1_150_1_141.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold1_0/checkpoint_model1_1_39.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold2/checkpoint_model4_2_93.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold3/checkpoint_model5_3_99.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold3/checkpoint_model5_3_74.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold4/checkpoint_model6_4_99.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold4/checkpoint_model6_4_98.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold5/checkpoint_model7_5_96.pth",
              "/home/sentic/storage2/iccv_madu/checkpoints/model1_basicAUG_fold5/checkpoint_model7_5_81.pth",

              ]

# checkpoint_dir = "/home/sentic/Documents/data/storage2/LEUKEMIA/C-NMC_Leukemia/checkpoints/"
device = torch.device("cuda:" + str(cuda_device_index) if torch.cuda.is_available() else "cpu")
prepath = ""
# replacer = "/home/sentic/Documents/data/storage2/LEUKEMIA/C-NMC_Leukemia"
replacer = ""
clip_len = 128

# %%
with open(fold_test_path) as fhandle:
    fold_splitter_test = json.load(fhandle)
    
def find_frames_by_name(fname, paths=fold_splitter_test["1"]["paths"],
                        frames=fold_splitter_test["1"]["frames"]):
    for ix, (p, f) in enumerate(zip(paths, frames)):
        if p == fname:
            return f
    return 0

def transfer_negative_to_positive(old_list, threshold=0.5):
    new_list = []
    for tup in old_list:
        if tup[0] == 1:
            new_list.append(tup)
        else:
            if tup[1] >= threshold:
                new_list.append(tup)
    return new_list

def choose_best_option(predictions_for_input, method="highest",
                      threshold=None):
    if method == "highest":
        if threshold is not None:
            predictions_for_input = [x for x in predictions_for_input if x[0] == 1 or (x[0] == 0 and x[1] >= threshold)]
        return sorted(predictions_for_input, key=lambda x: x[1], reverse=True)[0]
    elif method == "frequent":
        if threshold is None:
            threshold = 0.5
        list_positive = [x for x in predictions_for_input if x[0] == 1 if x[1] >= threshold]
        list_negative = [x for x in predictions_for_input if x[0] == 0 if x[1] >= threshold]
        if len(list_positive) > len(list_negative):
            if len(list_positive) > 0:
                return sorted(list_positive, key=lambda x: x[1], reverse=True)[0]
        else:
            if len(list_negative) > 0:
                return sorted(list_negative, key=lambda x: x[1], reverse=True)[0]
        return sorted(predictions_for_input, key=lambda x: x[1], reverse=True)[0]
    elif method == "weight":
        if threshold is not None:
            predictions_for_input = [x for x in predictions_for_input if x[0] == 1 or (x[0] == 0 and x[1] >= threshold)]
        list_positive = [x for x in predictions_for_input if x[0] == 1]
        list_negative = [x for x in predictions_for_input if x[0] == 0]
        score_positive, score_negative = 0, 0
        if len(list_positive) > 0:
            score_positive = sum([x[1] for x in list_positive]) / len(list_positive)
        if len(list_negative) > 0:
            score_negative = sum([x[1] for x in list_negative]) / len(list_negative)
        if score_positive >= score_negative:
            return (1, score_positive)
        else:
            return (0, score_negative)
        return sorted(predictions_for_input, key=lambda x: x[1], reverse=True)[0]

# %%
dataset_test = CTDatasetTestSimple(root=root, 
                      fold_id=fold_id, 
                      fold_splitter=fold_splitter_test,
                      transforms=None,
                      replacer="",
                      prepath="",
                      clip_len=clip_len,
                      split="test"
                      )

dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# %%
def simple_inference(inputs, leap=0, backward=False, 
                     flipx=False, flipy=False, 
                     original_num_frames=0, 
                     offset=0):
    inputs_clone = inputs.clone().detach()
    if backward == True:
        inputs1 = inputs_clone[:, :, :original_num_frames, :, :]
        inputs1 = torch.flip(inputs1, (2,))
        inputs2 = inputs_clone[:, :, original_num_frames:, :, :]
        inputs_clone = torch.cat([inputs1, inputs2], axis=2)
        del inputs1
        del inputs2
        
    if flipx == True:
        inputs_clone = torch.flip(inputs_clone, (3,))
        
    if flipy == True:
        inputs_clone = torch.flip(inputs_clone, (4,))
        
    if leap != 0:
        inputs_clone = inputs_clone[:, :, offset::leap, :, :]
    return inputs_clone

def decide_score(predictions, predictions_for_input):
    scores = torch.nn.functional.softmax(predictions, dim=1)
    predictions_for_input.append((1, scores[0][1].item()))
    predictions_for_input.append((0, scores[0][0].item()))
    return predictions_for_input

# %%
import torch.nn as nn
import torch
from tqdm import tqdm 
d = {}
scores_list = []

threshold_mapper = {0: [0.6, 0.38],
                    1: [0.6, 0.35],
                    2: [0.65, 0.48],
                    
                    3: [0.6, 0.35],
                    
                    4: [0.6, 0.35], 
                    5: [0.75, 0.45],
                    
                    6: [0.55, 0.45],
                    7: [0.55, 0.45],
                    
                    8: [0.65, 0.45],
                    9: [0.7, 0.4]
                   }

for ix_model, path_checkpoint in tqdm(enumerate(model_paths)):
    dict_checkpoint = torch.load(path_checkpoint, map_location='cuda:' + str(cuda_device_index))
    net_state_dict = dict_checkpoint['model_state_dict']

    model = i3_res50_nl(n_class)


    model.load_state_dict(net_state_dict)
    model.to(device)
    model.eval()
    ######################
    with torch.no_grad():
        for batch in dataloader_test:
            inputs, targets = (b.to(device) for b in batch[:2])
            fname = batch[2][0]
            
            if fname not in d:
                d[fname] = {"true": [targets.item()], "predicted": []}
                
            T = inputs.shape[2]
            predictions_for_input = []
            original_num_frames = inputs.shape[2]
            
            if T <= clip_len:
                original_num_frames = find_frames_by_name(fname)
                #################################################
                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=False, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################
                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=False, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=True, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=False, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=True, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=True, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=False, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=True, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

            elif T > clip_len and T <= 2 * clip_len:
                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=False, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################
                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=False, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ###################################################


                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=True, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=False, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=False, flipx=True, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=True, flipy=False, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=False, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################

                inputs1 = simple_inference(inputs, leap=0, backward=True, flipx=True, flipy=True, 
                         original_num_frames=original_num_frames, offset=0)
                predictions = model(inputs1) # forward input
                del inputs1
                predictions_for_input = decide_score(predictions, predictions_for_input)
                ##################################################
            elif T > 2 * clip_len and T <= 4 * clip_len:
                leap = 2
                for offset in range(leap):
                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=False, flipy=False, 
                                               original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1)
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=False, flipy=False, 
                                               original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1)
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ### 
                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=True, flipy=False, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=False, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=True, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=True, flipy=False, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=False, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=True, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################
            elif T > 4 * clip_len:
                leap = 3
                for offset in range(leap):
                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=False, flipy=False, 
                                               original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1)
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=False, flipy=False, 
                                               original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1)
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)

                    ### 
                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=True, flipy=False, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=False, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=False, flipx=True, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=True, flipy=False, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=False, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################

                    inputs1 = simple_inference(inputs, leap=leap, backward=True, flipx=True, flipy=True, 
                             original_num_frames=original_num_frames, offset=offset)
                    predictions = model(inputs1) # forward input
                    del inputs1
                    predictions_for_input = decide_score(predictions, predictions_for_input)
                    ##################################################
            else:
                print("NOT GOOD")
            new_list = transfer_negative_to_positive(predictions_for_input, 
                                                     threshold=threshold_mapper[ix_model][0])
            best_option = choose_best_option(new_list, method="frequent",
                                             threshold=threshold_mapper[ix_model][1])
            d[fname]["predicted"].append(best_option)
# Out:
# 10it [11:31:53, 4151.40s/it]

# %%
trues = []
predicted = []
fnames = []

for fname in d:
    new_list = transfer_negative_to_positive(d[fname]["predicted"], threshold=0.6)
    best_option = choose_best_option(new_list, method="frequent", threshold=0.38)
    trues.append(d[fname]["true"][0])
    predicted.append(best_option[0])
    fnames.append(fname)

# %%
from sklearn.metrics import classification_report
print(classification_report(trues, predicted, target_names=['non-covid', 'covid']))
# Out:
#               precision    recall  f1-score   support
#
#    non-covid       0.92      0.96      0.94       209
#        covid       0.95      0.90      0.92       165
#
#     accuracy                           0.93       374
#    macro avg       0.94      0.93      0.93       374
# weighted avg       0.93      0.93      0.93       374

# %%
from sklearn.metrics import f1_score
print(f1_score(trues, predicted, average='macro'))
# Out:
# 0.9317851853473119

# %%
# ### create extra_training_data ###
# threshold_score = 0.85
# metadata = []
# paths = []
# frames = []

# for fname in d:
#     new_list = transfer_negative_to_positive(d[fname]["predicted"], threshold=0.6)
#     best_option = choose_best_option(new_list, method="frequent", threshold=0.35)
#     if best_option[1] >= threshold_score:
#         paths.append(fname)
#         metadata.append(best_option[0])
#         frames.append(len(os.listdir(fname)))

# %%
# fold_splitter_path = "./train_folding.json"
# with open(fold_splitter_path) as fhandle:
#     fold_splitter = json.load(fhandle)
    
# fold_id = "1"
# print("BEFORE: {}".format(len(fold_splitter[fold_id]["paths"])))
# fold_splitter[fold_id]["paths"] += paths
# fold_splitter[fold_id]["metadata"] += metadata
# fold_splitter[fold_id]["frames"] += frames
# print("AFTER: {}".format(len(fold_splitter[fold_id]["paths"])))

# %%
# with open("./train_folding_extended.json", "w") as fhandle:
#     json.dump(fold_splitter, fhandle)

# %%
with open("./results_test.json", "w") as fhandle:
    json.dump(d, fhandle)

# %%
with open("./results_test.json", "r") as fhandle:
    d_copy = json.load(fhandle)

# %%
covid_fnames = []
non_covid_fnames = []

for fname in d:
    new_list = transfer_negative_to_positive(d[fname]["predicted"], threshold=0.6)
    best_option = choose_best_option(new_list, method="frequent", threshold=0.45)
    if best_option[0] == 1:
        covid_fnames.append(fname)
    elif best_option[0] == 0:
        non_covid_fnames.append(fname)

# %%
counter = 0
for fname in d:
    if 1 in [x[0] for x in d[fname]["predicted"]]:
        counter += 1
        new_list = transfer_negative_to_positive(d[fname]["predicted"], threshold=0.6)
        best_option = choose_best_option(new_list, method="frequent", threshold=0.38)
        if best_option[0] != 1:
            print(fname)
            print(d[fname]["predicted"])
            print("=======================")
# Out:
# /home/sentic/storage2/iccv_test_madu/b0726b3d-7209-42d5-89c3-4341d6e94428
# [(0, 0.8568363785743713), (0, 0.8119749426841736), (0, 0.7469034194946289), (0, 0.8241770267486572), (0, 0.8128288388252258), (1, 0.4025362730026245), (0, 0.8368515372276306), (0, 0.8100530505180359), (0, 0.7337502241134644), (1, 0.5286867022514343)]
# =======================
# /home/sentic/storage2/iccv_test_madu/79a5f3be-19d7-4ade-ab54-5445e0c04933
# [(1, 0.7517554759979248), (1, 0.7031927108764648), (1, 0.7231772541999817), (0, 0.9472662210464478), (0, 0.9195094108581543), (0, 0.8558757901191711), (0, 0.8583729267120361), (0, 0.8133707642555237), (0, 0.9096192717552185), (0, 0.9142037034034729)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0a11a9f9-360e-49e7-9bb9-aa71418b4443
# [(0, 0.8833084106445312), (1, 0.6956508159637451), (0, 0.7644441723823547), (0, 0.8991993069648743), (0, 0.8682643175125122), (0, 0.7717032432556152), (0, 0.8924641609191895), (0, 0.885351836681366), (0, 0.8858034014701843), (0, 0.8866801857948303)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9941b8f2-91d7-486c-a1b4-46b00af53d06
# [(0, 0.7798717617988586), (0, 0.774331271648407), (0, 0.7616405487060547), (0, 0.8953195810317993), (0, 0.832631528377533), (1, 0.4066561460494995), (0, 0.6688570976257324), (0, 0.678012490272522), (0, 0.7898458242416382), (0, 0.7965861558914185)]
# =======================
# /home/sentic/storage2/iccv_test_madu/050929e2-620d-401d-ac71-3f181efe94ef
# [(0, 0.8794946074485779), (0, 0.8650492429733276), (0, 0.7903534173965454), (1, 0.4775982201099396), (0, 0.886237621307373), (0, 0.8687843680381775), (0, 0.8512626886367798), (0, 0.843527615070343), (0, 0.8579555153846741), (0, 0.8469582200050354)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b89d80cb-a9e2-4d8b-aefb-3dea19f5126e
# [(1, 0.4391638934612274), (0, 0.7718461751937866), (0, 0.7130045294761658), (0, 0.8475373983383179), (0, 0.8089837431907654), (0, 0.7890294194221497), (0, 0.819443941116333), (0, 0.8113706111907959), (0, 0.8299906253814697), (0, 0.8369643092155457)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2ba92958-5bc8-465f-9070-435b700f81d8
# [(1, 0.6538610458374023), (1, 0.8014953136444092), (1, 0.7006927132606506), (0, 0.9325175285339355), (0, 0.8684856295585632), (0, 0.8321161866188049), (0, 0.9387404322624207), (0, 0.9280939698219299), (0, 0.8865452408790588), (0, 0.8884881138801575)]
# =======================
# /home/sentic/storage2/iccv_test_madu/21a9203b-96fb-4eef-9c47-d7e7d7a5b67a
# [(0, 0.903032660484314), (0, 0.8538979291915894), (0, 0.6572015285491943), (1, 0.6671155095100403), (1, 0.5273924469947815), (0, 0.8692807555198669), (0, 0.8841046094894409), (0, 0.8763668537139893), (1, 0.5056862235069275), (1, 0.6322228312492371)]
# =======================
# /home/sentic/storage2/iccv_test_madu/fa09000d-f6d9-4fd6-9a3d-2e5a6fa73a23
# [(0, 0.8683590292930603), (0, 0.8323594331741333), (0, 0.7185075879096985), (1, 0.4918443262577057), (1, 0.5381712913513184), (0, 0.799120306968689), (0, 0.698805034160614), (0, 0.7092081904411316), (0, 0.7020946741104126), (1, 0.7366998195648193)]
# =======================
# /home/sentic/storage2/iccv_test_madu/72a52b55-5144-4cb3-9931-1cb25882e0f2
# [(0, 0.8998088836669922), (0, 0.8500962853431702), (0, 0.8163849115371704), (0, 0.9018025398254395), (0, 0.77150559425354), (1, 0.5787057280540466), (0, 0.9156477451324463), (0, 0.9059423804283142), (0, 0.9063741564750671), (0, 0.9017344117164612)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a227fb8e-4f44-4a0f-89aa-ab036ec37dbc
# [(0, 0.8612651228904724), (0, 0.7861005663871765), (0, 0.7850602865219116), (0, 0.8158897757530212), (0, 0.7566494941711426), (0, 0.7538787722587585), (0, 0.735374927520752), (0, 0.6830601096153259), (1, 0.8722860813140869), (1, 0.8821321129798889)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6306a1e2-300d-436f-854f-9f11777b4291
# [(1, 0.5448182225227356), (0, 0.9167226552963257), (1, 0.6931984424591064), (0, 0.952095627784729), (0, 0.9313523769378662), (0, 0.9243724346160889), (0, 0.9559644460678101), (0, 0.9431635737419128), (1, 0.6773080825805664), (1, 0.6975796818733215)]
# =======================
# /home/sentic/storage2/iccv_test_madu/12364465-25c4-45bc-b06b-2c151c9ccdec
# [(0, 0.7585639953613281), (0, 0.7963166236877441), (1, 0.5763525366783142), (0, 0.804894208908081), (0, 0.8086473941802979), (0, 0.8277710676193237), (0, 0.8498477935791016), (0, 0.8424806594848633), (0, 0.790023148059845), (0, 0.7827345132827759)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9e0b2b5c-1018-447b-a000-d88ec2c2f6a2
# [(0, 0.8718509674072266), (0, 0.8096058368682861), (0, 0.6937488317489624), (0, 0.8405274152755737), (0, 0.7954214215278625), (0, 0.8065699338912964), (0, 0.7800883054733276), (0, 0.7620041370391846), (0, 0.7905780673027039), (1, 0.4941021203994751)]
# =======================
# /home/sentic/storage2/iccv_test_madu/54061078-9b0e-465e-8be1-8cefe85e33fe
# [(0, 0.8800556063652039), (1, 0.46560946106910706), (0, 0.7514175772666931), (0, 0.9740777015686035), (0, 0.9407521486282349), (0, 0.9128623604774475), (0, 0.9397254586219788), (0, 0.9325973987579346), (0, 0.9368374347686768), (0, 0.9147096276283264)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c34c07e8-d7a0-43dc-bf21-ceb2cc3ec027
# [(0, 0.8008071780204773), (0, 0.817831814289093), (1, 0.5682417750358582), (1, 0.7411320805549622), (1, 0.7045225501060486), (1, 0.5667809844017029), (0, 0.7264625430107117), (0, 0.6857864260673523), (0, 0.7467572689056396), (0, 0.7681195139884949)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b753af68-32ce-4f03-8b2c-81b8ad28e64a
# [(0, 0.8696671724319458), (0, 0.8503096103668213), (0, 0.8356285095214844), (0, 0.8807486891746521), (0, 0.8620699644088745), (0, 0.8258733749389648), (0, 0.8447815179824829), (0, 0.8321717977523804), (0, 0.7096331119537354), (1, 0.5027925968170166)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2bd89b81-f9eb-40a1-9636-fda281f509a7
# [(0, 0.7095714807510376), (0, 0.7616550922393799), (0, 0.6879317760467529), (1, 0.4709881842136383), (0, 0.725884199142456), (1, 0.5533165335655212), (0, 0.7544692158699036), (0, 0.7642844319343567), (0, 0.7661439776420593), (0, 0.8005776405334473)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8c5a8edd-b2df-4045-b3b1-dbc2d3ce28d8
# [(0, 0.9132648706436157), (1, 0.7668622732162476), (0, 0.8461524248123169), (0, 0.9247625470161438), (0, 0.946984052658081), (0, 0.924713134765625), (0, 0.9378339648246765), (0, 0.9291375875473022), (0, 0.9460535645484924), (0, 0.9442577362060547)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8be3751c-3dbd-41ac-ac25-6762a763354d
# [(1, 0.7224725484848022), (1, 0.7848726511001587), (0, 0.6622746586799622), (0, 0.8922165036201477), (0, 0.8885973691940308), (0, 0.8723439574241638), (0, 0.8369959592819214), (0, 0.8356693983078003), (0, 0.8700082898139954), (0, 0.8412479162216187)]
# =======================
# /home/sentic/storage2/iccv_test_madu/1cee4dc1-21ef-4696-8214-b23ce9835c4e
# [(0, 0.7760841250419617), (1, 0.6909968852996826), (0, 0.6966241598129272), (0, 0.8972522020339966), (0, 0.890011191368103), (0, 0.8378405570983887), (0, 0.8810751438140869), (0, 0.8796426057815552), (0, 0.7404196262359619), (0, 0.7925840616226196)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b00308ba-09cd-4bcd-848e-5725aed9bc58
# [(0, 0.723341166973114), (1, 0.5656231641769409), (1, 0.5763166546821594), (0, 0.7984960079193115), (0, 0.8476864099502563), (0, 0.8283093571662903), (0, 0.8114385604858398), (0, 0.8062362670898438), (0, 0.7391790747642517), (1, 0.6017009615898132)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a43be293-848a-4f02-a7d4-1822e55c93da
# [(0, 0.8980004191398621), (0, 0.8863585591316223), (0, 0.8903147578239441), (0, 0.8905496597290039), (0, 0.8662946820259094), (0, 0.8450984954833984), (0, 0.8728975057601929), (0, 0.8589834570884705), (1, 0.5532050132751465), (1, 0.6283453702926636)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7e764f27-430a-4516-a286-fdd1a21b32e8
# [(1, 0.6818148493766785), (1, 0.6279824376106262), (1, 0.534013569355011), (0, 0.9014374017715454), (0, 0.7274824976921082), (1, 0.41047993302345276), (0, 0.7878641486167908), (0, 0.7810095548629761), (0, 0.7640296220779419), (1, 0.6157640814781189)]
# =======================
# /home/sentic/storage2/iccv_test_madu/1753afb3-94d7-466d-b4c9-afea2bc97130
# [(0, 0.8807399868965149), (0, 0.857124924659729), (0, 0.7878404259681702), (1, 0.49698206782341003), (0, 0.8668952584266663), (0, 0.8438100814819336), (0, 0.8681000471115112), (0, 0.8624398112297058), (0, 0.8649634718894958), (0, 0.8651834726333618)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a0cffa66-41c7-48af-98a7-e93694e596e8
# [(1, 0.6360043287277222), (1, 0.6983139514923096), (1, 0.5124981999397278), (0, 0.7299795150756836), (0, 0.8138169646263123), (0, 0.7953556180000305), (0, 0.8282365202903748), (0, 0.8182438611984253), (1, 0.656029999256134), (1, 0.6054115295410156)]
# =======================
# /home/sentic/storage2/iccv_test_madu/53e794a3-7621-4e6e-bbb3-0f729aed46f6
# [(1, 0.7554309368133545), (1, 0.8090502619743347), (1, 0.594367504119873), (0, 0.8787103295326233), (0, 0.8879678249359131), (0, 0.8421255350112915), (0, 0.798018217086792), (0, 0.7709475755691528), (0, 0.7981091737747192), (0, 0.8011080026626587)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3a941597-b9a9-4cfb-9f00-c1d48a96f2b5
# [(0, 0.8340538144111633), (1, 0.5032729506492615), (0, 0.7889270782470703), (0, 0.8769821524620056), (0, 0.8836904168128967), (0, 0.7970353364944458), (0, 0.9305990934371948), (0, 0.915418803691864), (0, 0.8845366835594177), (0, 0.9311703443527222)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9507ab8f-0e58-4f75-af80-c86584b71a4b
# [(0, 0.8724693059921265), (0, 0.8304252028465271), (0, 0.7321706414222717), (0, 0.9335315227508545), (1, 0.8117355704307556), (1, 0.8459832072257996), (0, 0.9318885207176208), (0, 0.9255380630493164), (0, 0.9295792579650879), (0, 0.9238318800926208)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0c7bad17-f5d8-4d6e-9d89-df0d93add5cc
# [(1, 0.6863647103309631), (1, 0.6440024971961975), (1, 0.7147142291069031), (0, 0.9039453864097595), (0, 0.9273263216018677), (0, 0.8537863492965698), (0, 0.8109026551246643), (0, 0.7653865814208984), (1, 0.6175441741943359), (1, 0.5778889060020447)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cf8d8e2c-a83d-43b5-be16-6321c88329ae
# [(1, 0.7061612606048584), (1, 0.6267997026443481), (1, 0.7434203028678894), (0, 0.9935547709465027), (0, 0.9590728282928467), (0, 0.8215870261192322), (0, 0.6991727352142334), (0, 0.6353200078010559), (0, 0.7031294107437134), (1, 0.4704093039035797)]
# =======================
# /home/sentic/storage2/iccv_test_madu/18047c45-560c-4b01-8e1d-45010d949dd0
# [(0, 0.8858007788658142), (0, 0.8603843450546265), (0, 0.7572415471076965), (0, 0.8928238749504089), (0, 0.9062690138816833), (0, 0.8790594935417175), (0, 0.8940753936767578), (0, 0.8873449563980103), (0, 0.809847354888916), (1, 0.6394403576850891)]
# =======================
# /home/sentic/storage2/iccv_test_madu/1466018c-bdfd-4571-ada4-437dcfeb2b59
# [(0, 0.8230373859405518), (0, 0.7704220414161682), (0, 0.7020807862281799), (0, 0.7055118083953857), (0, 0.8250240087509155), (1, 0.5163830518722534), (0, 0.8621050715446472), (0, 0.8567858934402466), (0, 0.8696495890617371), (0, 0.8732055425643921)]
# =======================
# /home/sentic/storage2/iccv_test_madu/66e6dbb3-710f-4a22-82ae-882e2f4b574d
# [(0, 0.8921558856964111), (0, 0.8560667037963867), (0, 0.6774996519088745), (1, 0.5319465398788452), (0, 0.834318995475769), (0, 0.7982144355773926), (0, 0.8852075338363647), (0, 0.8888953924179077), (0, 0.8521342277526855), (1, 0.6196330189704895)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3aa7ce0c-627f-47d3-872e-f9cb2cd93ff1
# [(0, 0.9475705623626709), (0, 0.95090252161026), (0, 0.9164226651191711), (0, 0.9581670761108398), (0, 0.9446731805801392), (0, 0.9067060947418213), (0, 0.9360790848731995), (0, 0.9241865873336792), (0, 0.7447415590286255), (1, 0.4961172640323639)]
# =======================
# /home/sentic/storage2/iccv_test_madu/33347b82-4656-4206-8624-b4a2ef258708
# [(0, 0.8088136911392212), (0, 0.7997279763221741), (1, 0.5888359546661377), (0, 0.8865744471549988), (0, 0.8067157864570618), (0, 0.8079941868782043), (0, 0.8019083738327026), (0, 0.7552427649497986), (1, 0.5929903388023376), (1, 0.6459640264511108)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c9a2033a-36a6-4a06-ba05-71c60369e19c
# [(0, 0.9504730701446533), (0, 0.9144043922424316), (1, 0.7895309329032898), (1, 0.9113868474960327), (0, 0.8007089495658875), (1, 0.4938632547855377), (0, 0.7983320951461792), (0, 0.8155038952827454), (0, 0.9662448167800903), (0, 0.9670966267585754)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4c6c66eb-9da5-4e27-800f-e9fa7660cd77
# [(0, 0.8808464407920837), (1, 0.5869478583335876), (0, 0.7416265606880188), (0, 0.9075706005096436), (0, 0.9051519632339478), (0, 0.8781887292861938), (0, 0.8878601789474487), (0, 0.884543240070343), (0, 0.9019201993942261), (0, 0.9021844267845154)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2608416b-111a-4408-a704-5e7ea3e3d6bc
# [(0, 0.7140352725982666), (0, 0.7626537084579468), (0, 0.6845942139625549), (0, 0.6662636995315552), (0, 0.7480672001838684), (1, 0.5223029851913452), (0, 0.7523941397666931), (0, 0.7555276155471802), (0, 0.7761896848678589), (0, 0.8040251731872559)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a51f5c63-57b5-4e71-adbd-a21a8b42696f
# [(0, 0.7673873901367188), (0, 0.7934420108795166), (1, 0.5486593842506409), (1, 0.5169674754142761), (0, 0.8102527260780334), (0, 0.7971287369728088), (0, 0.6972022652626038), (0, 0.6888967752456665), (0, 0.7052204012870789), (0, 0.764677882194519)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c33b8da4-beea-443d-abc2-1aeba375f8e3
# [(0, 0.8758129477500916), (1, 0.7486466765403748), (1, 0.6069485545158386), (0, 0.9024075269699097), (0, 0.8969069123268127), (0, 0.878368616104126), (0, 0.8939318060874939), (0, 0.8736989498138428), (0, 0.8813884258270264), (1, 0.5626801252365112)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c61629eb-f73d-4821-bab3-d5073a62477d
# [(0, 0.7716023325920105), (0, 0.7921783924102783), (0, 0.6901604533195496), (1, 0.5037229061126709), (1, 0.5807417035102844), (1, 0.5732548236846924), (0, 0.6439605951309204), (0, 0.6257725358009338), (0, 0.6740728616714478), (1, 0.4578912556171417)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9220d299-fa85-41d9-8ac0-6325c18e875b
# [(0, 0.8160122036933899), (1, 0.5013394951820374), (0, 0.8973063230514526), (0, 0.9500665664672852), (0, 0.9442026615142822), (0, 0.9088259339332581), (0, 0.9372029304504395), (0, 0.934614896774292), (0, 0.9447793364524841), (0, 0.885063111782074)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0b4aefb7-7f09-4cb1-812d-22ac2a9a2b84
# [(0, 0.8787274360656738), (0, 0.8603318333625793), (0, 0.8637314438819885), (0, 0.7649780511856079), (0, 0.8740348219871521), (0, 0.8503783345222473), (0, 0.8308305144309998), (0, 0.8287623524665833), (1, 0.689232587814331), (1, 0.6950637698173523)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0f359af9-135c-4a2a-b8e0-6d4fa893a965
# [(1, 0.775713324546814), (1, 0.8490213751792908), (1, 0.5583270788192749), (0, 0.791272759437561), (1, 0.5301273465156555), (1, 0.5097602605819702), (0, 0.9038416743278503), (0, 0.8997719287872314), (0, 0.9068264365196228), (0, 0.9078263640403748)]
# =======================
# /home/sentic/storage2/iccv_test_madu/77dc0267-c4fb-4658-9804-7acb2776b4f8
# [(1, 0.733923614025116), (1, 0.7852060794830322), (1, 0.7533940076828003), (0, 0.8888113498687744), (0, 0.9422764778137207), (0, 0.9294916987419128), (0, 0.8249578475952148), (0, 0.7733721137046814), (0, 0.8956171274185181), (0, 0.886325478553772)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9ae41dbc-2b19-4f01-9e93-25369c1b6b62
# [(0, 0.8933725953102112), (0, 0.8757236003875732), (0, 0.7983394265174866), (0, 0.8570383191108704), (0, 0.9141998291015625), (0, 0.8912032842636108), (0, 0.9187722206115723), (0, 0.9181784987449646), (1, 0.5387845039367676), (1, 0.49648910760879517)]
# =======================
# /home/sentic/storage2/iccv_test_madu/aeca1257-781b-4645-b894-ef98bc9a7875
# [(1, 0.5459921360015869), (0, 0.7813153862953186), (1, 0.526174008846283), (0, 0.9048028588294983), (0, 0.7933134436607361), (0, 0.7926223278045654), (0, 0.8756346702575684), (0, 0.8358922004699707), (0, 0.822267472743988), (0, 0.81686931848526)]
# =======================
# /home/sentic/storage2/iccv_test_madu/48f84e7e-d092-425d-9cfd-7049b3c871b7
# [(0, 0.9366369843482971), (0, 0.93760746717453), (0, 0.890870988368988), (0, 0.9304131865501404), (0, 0.9311684370040894), (0, 0.8740844130516052), (0, 0.9364391565322876), (0, 0.9240058064460754), (0, 0.7345157861709595), (1, 0.47497087717056274)]
# =======================
# /home/sentic/storage2/iccv_test_madu/5f42c956-060b-4ce3-81a8-93fe54f2ca32
# [(0, 0.8057616949081421), (0, 0.8062782287597656), (1, 0.5417121052742004), (1, 0.5855314135551453), (0, 0.7728077173233032), (1, 0.6202377080917358), (0, 0.7878316640853882), (0, 0.792296826839447), (1, 0.5755366683006287), (1, 0.6031328439712524)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bce679a5-f2b4-4797-971c-c59473220197
# [(0, 0.8964555859565735), (0, 0.8956246972084045), (0, 0.8600776195526123), (0, 0.8908286094665527), (0, 0.8866561055183411), (0, 0.8566445708274841), (0, 0.9337500929832458), (0, 0.913999617099762), (1, 0.6861461997032166), (1, 0.6210317015647888)]
# =======================
# /home/sentic/storage2/iccv_test_madu/23b53cd8-0f03-486b-866b-f69b73f4ad2b
# [(0, 0.7801754474639893), (0, 0.7588483691215515), (1, 0.49715715646743774), (0, 0.7834144830703735), (1, 0.7703251242637634), (1, 0.7849780917167664), (0, 0.757753312587738), (0, 0.801933765411377), (0, 0.8223709464073181), (0, 0.8047739267349243)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c7602518-02fd-49e8-9cac-500e36df1525
# [(0, 0.8758543729782104), (0, 0.8521245718002319), (0, 0.795552670955658), (0, 0.8724220991134644), (0, 0.8586611151695251), (0, 0.8575692772865295), (1, 0.8948320746421814), (1, 0.845895528793335), (0, 0.8005748391151428), (1, 0.8655365705490112)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cc9675a0-f284-4718-b0f1-3feeb2b563c7
# [(0, 0.8712297081947327), (0, 0.8652370572090149), (1, 0.5222280621528625), (1, 0.6310369968414307), (0, 0.7771263718605042), (1, 0.6350379586219788), (0, 0.7898702025413513), (0, 0.778059184551239), (0, 0.7140719294548035), (1, 0.5638108849525452)]
# =======================
# /home/sentic/storage2/iccv_test_madu/59e9c499-8c84-4369-bb50-c05261a078dc
# [(0, 0.7774842977523804), (1, 0.43209534883499146), (0, 0.7576987147331238), (0, 0.8388844728469849), (0, 0.8351929783821106), (0, 0.8197042346000671), (0, 0.7932909727096558), (0, 0.7795407772064209), (0, 0.7189902663230896), (1, 0.44488826394081116)]
# =======================
# /home/sentic/storage2/iccv_test_madu/22032252-1d40-49d1-9a6a-3db7c23d3db2
# [(0, 0.783064067363739), (1, 0.5016080141067505), (1, 0.4810698330402374), (0, 0.8646678328514099), (0, 0.8496462106704712), (0, 0.8123530745506287), (0, 0.7742910385131836), (0, 0.779902994632721), (0, 0.7659084796905518), (0, 0.8257260322570801)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b4b56517-0545-4cc0-832d-d50b7c81acc4
# [(0, 0.8586682081222534), (0, 0.7844407558441162), (0, 0.7184819579124451), (0, 0.8313363790512085), (0, 0.7998528480529785), (0, 0.7705591917037964), (0, 0.6806869506835938), (0, 0.6845332980155945), (1, 0.8955033421516418), (1, 0.9060655832290649)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6dc66fdb-2493-45df-8eef-16cfa49d6c65
# [(1, 0.6174612641334534), (1, 0.4924614131450653), (0, 0.734089195728302), (1, 0.6981748938560486), (1, 0.767586886882782), (1, 0.6360096335411072), (0, 0.8050819635391235), (0, 0.7531374096870422), (0, 0.7636626362800598), (0, 0.752143383026123)]
# =======================
# /home/sentic/storage2/iccv_test_madu/e4b50718-df7b-45d3-bdc8-50b18c563899
# [(1, 0.9104677438735962), (1, 0.9255743622779846), (1, 0.6792142391204834), (0, 0.7765780687332153), (0, 0.705973207950592), (1, 0.895107090473175), (0, 0.8026776909828186), (0, 0.8068570494651794), (0, 0.8558389544487), (1, 0.6778175830841064)]
# =======================
# /home/sentic/storage2/iccv_test_madu/451611b5-d57a-45af-bee8-d7fdfbc32e57
# [(0, 0.8489592671394348), (0, 0.8412631154060364), (1, 0.8639397025108337), (0, 0.9524021744728088), (0, 0.989547610282898), (0, 0.9074650406837463), (0, 0.8770846724510193), (0, 0.8551293015480042), (0, 0.9120561480522156), (0, 0.9128285050392151)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8e14a2f3-aa60-4b2b-a285-1e8e73c50544
# [(1, 0.6753817796707153), (1, 0.6781887412071228), (1, 0.5663418769836426), (0, 0.9164562225341797), (0, 0.9337134957313538), (0, 0.863098680973053), (0, 0.8780512809753418), (0, 0.8480929732322693), (0, 0.7848199009895325), (1, 0.5238795876502991)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9a7e16ad-b593-4045-aa74-a0e51cb0b171
# [(0, 0.8848006129264832), (0, 0.8190394043922424), (1, 0.7809017896652222), (0, 0.9878482818603516), (0, 0.995966911315918), (0, 0.9598372578620911), (0, 0.9165469408035278), (0, 0.9069232940673828), (0, 0.9219490885734558), (0, 0.9295796155929565)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6b1e69c7-913c-4022-a5f7-56473fcd1aa5
# [(0, 0.8898702263832092), (0, 0.8444728255271912), (0, 0.7746773362159729), (1, 0.5372915863990784), (0, 0.8829200863838196), (0, 0.8585671186447144), (0, 0.8891131281852722), (0, 0.8892090916633606), (1, 0.7060257196426392), (1, 0.758548378944397)]
# =======================
# /home/sentic/storage2/iccv_test_madu/45435e5a-9118-4ac6-8757-2f3e22f53be6
# [(0, 0.9087852835655212), (0, 0.8992222547531128), (0, 0.7454612255096436), (1, 0.7274089455604553), (0, 0.9131825566291809), (0, 0.8974247574806213), (0, 0.9126328229904175), (0, 0.9000982642173767), (0, 0.8771013617515564), (1, 0.5683034062385559)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bfe40589-0c7f-484f-9e05-101585f01b27
# [(0, 0.6999156475067139), (0, 0.6864309906959534), (0, 0.691214382648468), (1, 0.4707074463367462), (0, 0.7979286313056946), (0, 0.7820026278495789), (0, 0.832131028175354), (0, 0.828037440776825), (0, 0.9064350128173828), (0, 0.9047254323959351)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a648a6b3-9f6d-40d1-858d-50fc9acfcf86
# [(0, 0.872187077999115), (0, 0.7960504293441772), (0, 0.6926486492156982), (0, 0.8592960834503174), (0, 0.8704593181610107), (0, 0.847694993019104), (0, 0.7654893398284912), (0, 0.763190746307373), (1, 0.5842287540435791), (1, 0.6570433378219604)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c62c40c9-cfe0-45d1-b76e-8d9da5ac1e1a
# [(0, 0.874567449092865), (0, 0.8476160168647766), (0, 0.7833607196807861), (0, 0.7499006986618042), (0, 0.7862416505813599), (1, 0.5972867608070374), (0, 0.8455869555473328), (0, 0.8394111394882202), (0, 0.8470385074615479), (0, 0.8472827672958374)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a72c8b0d-9848-4f77-a10a-33a9156193b1
# [(1, 0.4486353397369385), (0, 0.8515409231185913), (0, 0.825016438961029), (0, 0.8743939995765686), (0, 0.8744776844978333), (0, 0.8570846319198608), (0, 0.8383705019950867), (0, 0.8327757120132446), (0, 0.8521979451179504), (0, 0.8017228841781616)]
# =======================
# /home/sentic/storage2/iccv_test_madu/273aeabf-e865-48c5-8b03-698c4f93e9fb
# [(1, 0.7751739621162415), (1, 0.7420237064361572), (0, 0.708807110786438), (0, 0.893208920955658), (0, 0.9015710949897766), (0, 0.8607833981513977), (0, 0.8844408392906189), (0, 0.8822319507598877), (0, 0.7419717907905579), (0, 0.7661470174789429)]
# =======================
# /home/sentic/storage2/iccv_test_madu/15c9319b-5143-4fd0-9a27-60a582f6a2bd
# [(0, 0.7055412530899048), (0, 0.7939595580101013), (0, 0.7756554484367371), (0, 0.8800027966499329), (0, 0.7624393701553345), (0, 0.788029134273529), (1, 0.7195477485656738), (1, 0.7247757315635681), (1, 0.5949435830116272), (1, 0.5923442244529724)]
# =======================
# /home/sentic/storage2/iccv_test_madu/15d61c8b-68a8-46ab-a6b0-6e54e36a64f3
# [(0, 0.7870966196060181), (0, 0.8272656202316284), (0, 0.7141717076301575), (0, 0.8486949801445007), (0, 0.8071503639221191), (0, 0.7880153656005859), (0, 0.7936949729919434), (0, 0.7961685061454773), (0, 0.7319467067718506), (1, 0.4962761700153351)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8e61d11b-4b56-4e5c-b337-dffd4d2f2d70
# [(1, 0.7598413825035095), (1, 0.7075116634368896), (1, 0.6701522469520569), (0, 0.8731705546379089), (0, 0.8558998107910156), (0, 0.7775906324386597), (0, 0.8295389413833618), (0, 0.8158161044120789), (0, 0.7057037353515625), (1, 0.4882448613643646)]
# =======================
# /home/sentic/storage2/iccv_test_madu/80d4ce94-c35f-4290-a90d-733c596b399d
# [(0, 0.8886175155639648), (0, 0.8723865151405334), (0, 0.7396407127380371), (0, 0.8003906607627869), (0, 0.8800686001777649), (0, 0.863923192024231), (0, 0.6065854430198669), (0, 0.5973299741744995), (1, 0.44992709159851074), (1, 0.4475542902946472)]
# =======================
# /home/sentic/storage2/iccv_test_madu/480c5cf3-5812-4f3b-8820-d90ecddb939f
# [(0, 0.7882204651832581), (0, 0.7607949376106262), (0, 0.6555531620979309), (0, 0.7882209420204163), (1, 0.7458189725875854), (1, 0.6718112826347351), (0, 0.7722388505935669), (0, 0.8555495738983154), (0, 0.8322508335113525), (0, 0.8142863512039185)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0ef4f734-446a-4e71-82cd-459d5114e5e8
# [(0, 0.8775508999824524), (0, 0.8262226581573486), (0, 0.7854647636413574), (0, 0.8724069595336914), (0, 0.8182822465896606), (1, 0.43502628803253174), (0, 0.8631556034088135), (0, 0.8617805242538452), (0, 0.7580605149269104), (1, 0.6334908604621887)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9a6c8fc5-ee2c-4a13-9f01-702672a6eb62
# [(0, 0.912534236907959), (0, 0.9011334180831909), (0, 0.8510345816612244), (0, 0.9168161153793335), (0, 0.8500504493713379), (0, 0.8376303911209106), (0, 0.9019353985786438), (0, 0.8828616738319397), (1, 0.6584762334823608), (1, 0.7242187857627869)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9fa3dcf3-de1f-495b-b6ee-13ee116c6b65
# [(0, 0.870394766330719), (0, 0.8577938675880432), (1, 0.45674341917037964), (1, 0.5478240847587585), (0, 0.7844370007514954), (0, 0.7850256562232971), (0, 0.8681051731109619), (0, 0.8254238963127136), (0, 0.7203807830810547), (0, 0.8298373818397522)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bd549333-3de3-419a-8151-04bf651de721
# [(0, 0.8723620176315308), (0, 0.8558763861656189), (0, 0.846027135848999), (0, 0.8837144374847412), (0, 0.8648592233657837), (0, 0.8276793360710144), (0, 0.8499926328659058), (0, 0.8393948078155518), (0, 0.7225049734115601), (1, 0.49159127473831177)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4701a686-2fb1-4e8d-b184-3dc4f6e9fb57
# [(0, 0.7309472560882568), (0, 0.7377827167510986), (1, 0.49356821179389954), (0, 0.8795855045318604), (0, 0.8300990462303162), (0, 0.8602693676948547), (1, 0.8281947374343872), (1, 0.8796360492706299), (1, 0.7048052549362183), (1, 0.6664671897888184)]
# =======================
# /home/sentic/storage2/iccv_test_madu/54b9ee16-72ab-4c03-84b9-afd63c0feb39
# [(1, 0.6680654287338257), (1, 0.8017483353614807), (1, 0.7577143907546997), (0, 0.9277084469795227), (0, 0.8442494869232178), (0, 0.7751549482345581), (0, 0.9169602990150452), (0, 0.9035306572914124), (0, 0.8692428469657898), (0, 0.8809912800788879)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3a88b92e-f0b1-4fe7-ae17-140e03d2ea89
# [(1, 0.5272136330604553), (1, 0.5120565295219421), (0, 0.7021151781082153), (0, 0.8674163818359375), (1, 0.5300486087799072), (1, 0.6419051885604858), (0, 0.7570441365242004), (0, 0.7232891917228699), (0, 0.7393977046012878), (0, 0.7555318474769592)]
# =======================
# /home/sentic/storage2/iccv_test_madu/05ac6e93-a716-4b85-8fef-a235f3515a90
# [(0, 0.6821927428245544), (1, 0.5948155522346497), (0, 0.8828640580177307), (0, 0.8540201783180237), (1, 0.569681704044342), (1, 0.7944096326828003), (0, 0.819938600063324), (0, 0.815617561340332), (0, 0.8952186703681946), (0, 0.8731279969215393)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6842c40c-36f9-48cc-a2dd-8671bd8ccd62
# [(0, 0.8845236301422119), (0, 0.7816590070724487), (0, 0.7470999360084534), (0, 0.7232778072357178), (0, 0.8276218771934509), (1, 0.3967764675617218), (0, 0.7779854536056519), (0, 0.7706480026245117), (0, 0.8758066296577454), (0, 0.8842204213142395)]
# =======================
# /home/sentic/storage2/iccv_test_madu/5cb7bd6e-466f-472d-888b-84f90b9f8708
# [(0, 0.8888700604438782), (0, 0.861260712146759), (0, 0.8040886521339417), (0, 0.9040960073471069), (0, 0.8506451845169067), (0, 0.8271895051002502), (0, 0.8941638469696045), (0, 0.8849793672561646), (1, 0.4843868315219879), (1, 0.528549313545227)]
# =======================
# /home/sentic/storage2/iccv_test_madu/91c66a06-503a-4a92-829a-4a0d3fab31a6
# [(0, 0.8588113188743591), (0, 0.8381314873695374), (1, 0.5095351338386536), (0, 0.835176944732666), (0, 0.8751113414764404), (0, 0.8594253063201904), (0, 0.879288375377655), (0, 0.8781789541244507), (0, 0.8634361028671265), (0, 0.8690788745880127)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7824ce71-a952-42dd-8b39-d49924068887
# [(0, 0.7162333726882935), (0, 0.7629637718200684), (0, 0.6644335389137268), (1, 0.5222739577293396), (0, 0.7261810302734375), (1, 0.529440701007843), (0, 0.7170116901397705), (0, 0.7098524570465088), (0, 0.6835342645645142), (0, 0.7531549334526062)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8268a588-de6b-4d8f-b574-accca407ce47
# [(0, 0.670379102230072), (0, 0.7837448120117188), (0, 0.7592184543609619), (0, 0.8885343074798584), (0, 0.876769483089447), (1, 0.4186045229434967), (0, 0.7139529585838318), (0, 0.7913236021995544), (0, 0.7481438517570496), (0, 0.8294720649719238)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a7d742f0-7e35-46ae-b7bb-49b44b69086a
# [(1, 0.5452858209609985), (1, 0.617093563079834), (1, 0.6162800192832947), (0, 0.9039356708526611), (0, 0.8920922875404358), (0, 0.845176637172699), (0, 0.8217549324035645), (0, 0.8090978264808655), (0, 0.7554357647895813), (1, 0.5177903175354004)]
# =======================
# /home/sentic/storage2/iccv_test_madu/70f96d25-95b3-450b-8f04-3abba6e19d98
# [(0, 0.770049512386322), (1, 0.5087219476699829), (1, 0.5195863842964172), (0, 0.8299228549003601), (0, 0.7763598561286926), (0, 0.8415419459342957), (0, 0.7748537659645081), (0, 0.7913879156112671), (0, 0.7590001821517944), (0, 0.7575145959854126)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2b427f1a-087b-408d-9bc0-040d450792ac
# [(0, 0.7057921290397644), (1, 0.5239900350570679), (1, 0.4828988313674927), (0, 0.858559787273407), (0, 0.7567870020866394), (1, 0.4562682807445526), (0, 0.6978358030319214), (0, 0.7061231732368469), (1, 0.5334295034408569), (1, 0.585274875164032)]
# =======================
# /home/sentic/storage2/iccv_test_madu/73044e77-c245-48fb-b95e-be33ed8658ab
# [(0, 0.8143255710601807), (0, 0.8122681975364685), (0, 0.7671028971672058), (0, 0.8519448041915894), (0, 0.8057512640953064), (0, 0.7576284408569336), (0, 0.6930424571037292), (1, 0.605090856552124), (1, 0.5998706817626953), (1, 0.5141472816467285)]
# =======================
# /home/sentic/storage2/iccv_test_madu/11bffa9c-e43a-4521-ba18-5fb5d683b512
# [(0, 0.8412549495697021), (0, 0.8228055834770203), (0, 0.8656004071235657), (0, 0.8380367755889893), (1, 0.8219684362411499), (1, 0.9033486843109131), (0, 0.6507941484451294), (0, 0.6515468955039978), (0, 0.817112147808075), (0, 0.8042014241218567)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a641b97b-22d2-47bb-aa9f-b2724f692b0a
# [(0, 0.7521931529045105), (0, 0.9101711511611938), (1, 0.6357280015945435), (0, 0.8357552289962769), (0, 0.8626155257225037), (1, 0.6640790700912476), (0, 0.8953167796134949), (0, 0.8565863370895386), (0, 0.939697802066803), (0, 0.926918089389801)]
# =======================
# /home/sentic/storage2/iccv_test_madu/75f2fbe0-2ad1-4ef1-acff-d8ba1032dfa1
# [(0, 0.8863312005996704), (0, 0.8691949844360352), (0, 0.8472028970718384), (0, 0.9486145377159119), (0, 0.8376123309135437), (0, 0.7668620944023132), (0, 0.9002223014831543), (0, 0.8778815865516663), (1, 0.8757122755050659), (1, 0.907153308391571)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7d6c2854-b036-4605-9604-814f07a3416e
# [(0, 0.763976514339447), (0, 0.8163770437240601), (0, 0.8738344311714172), (0, 0.9865886569023132), (0, 0.9703327417373657), (0, 0.933067262172699), (0, 0.8960135579109192), (0, 0.8649898767471313), (0, 0.7422273755073547), (1, 0.5631133317947388)]
# =======================
# /home/sentic/storage2/iccv_test_madu/134ffe11-5769-4b25-91e6-ebc7462725b3
# [(1, 0.4782146215438843), (1, 0.6828859448432922), (1, 0.5977964401245117), (0, 0.8826805949211121), (0, 0.8052559494972229), (0, 0.7733971476554871), (0, 0.8690780997276306), (0, 0.8670594096183777), (0, 0.8583247661590576), (0, 0.812004804611206)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2cff0fd9-787c-4a9c-81d9-99b736669857
# [(0, 0.8584812879562378), (0, 0.8379347324371338), (0, 0.6730151772499084), (0, 0.7573708891868591), (0, 0.734229564666748), (1, 0.4689948558807373), (0, 0.7188919186592102), (0, 0.7232815623283386), (1, 0.7222775220870972), (1, 0.7317607998847961)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0e8843e2-c532-480b-9de2-f45146fd3695
# [(0, 0.870364248752594), (0, 0.8789905905723572), (1, 0.8141720294952393), (0, 0.9864197373390198), (0, 0.9924061894416809), (0, 0.9413564205169678), (0, 0.9236608147621155), (0, 0.9089708924293518), (0, 0.9364261031150818), (0, 0.9401746988296509)]
# =======================
# /home/sentic/storage2/iccv_test_madu/829025b6-ba7d-4736-94f0-8a081553d406
# [(1, 0.6749855279922485), (1, 0.6885287165641785), (0, 0.8331538438796997), (0, 0.8885313272476196), (0, 0.8902057409286499), (0, 0.8447086215019226), (0, 0.8974621891975403), (0, 0.8941168785095215), (0, 0.8908659219741821), (0, 0.8950142860412598)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8ddb6e48-2ae9-46d3-959b-ba2cad2a5c12
# [(0, 0.9005138278007507), (0, 0.8244572281837463), (0, 0.8014015555381775), (0, 0.9038861989974976), (1, 0.5464627742767334), (1, 0.5846942067146301), (0, 0.9126061201095581), (0, 0.9034423828125), (0, 0.9044952392578125), (0, 0.8992105722427368)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8dee4a30-6344-4846-9059-31db328189fc
# [(1, 0.5289498567581177), (0, 0.7586540579795837), (0, 0.7772321701049805), (0, 0.8450676798820496), (0, 0.8380936980247498), (0, 0.8854126334190369), (0, 0.82361900806427), (0, 0.8173874020576477), (0, 0.8716875314712524), (0, 0.8749641180038452)]
# =======================
# /home/sentic/storage2/iccv_test_madu/afca3955-4cf0-4bcf-906c-806b92c089ad
# [(1, 0.5235627293586731), (0, 0.805943489074707), (1, 0.6847738027572632), (0, 0.8434388041496277), (0, 0.8650690913200378), (0, 0.7715916633605957), (0, 0.8533786535263062), (0, 0.8414822816848755), (1, 0.6481844186782837), (1, 0.5728688836097717)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c378ec21-b79c-404e-a41e-f004e744a940
# [(1, 0.6236289143562317), (1, 0.7995297908782959), (1, 0.7449870705604553), (0, 0.9254010915756226), (0, 0.8548645377159119), (0, 0.8095705509185791), (0, 0.9215180277824402), (0, 0.913307785987854), (0, 0.8699947595596313), (0, 0.8917762041091919)]
# =======================
# /home/sentic/storage2/iccv_test_madu/27f679c9-914b-4044-8f25-847a01974408
# [(0, 0.8052375316619873), (0, 0.725553035736084), (0, 0.6574128866195679), (0, 0.8496551513671875), (0, 0.7634031176567078), (1, 0.4014616310596466), (0, 0.7138166427612305), (0, 0.703920304775238), (0, 0.7200598120689392), (0, 0.7896259427070618)]
# =======================
# /home/sentic/storage2/iccv_test_madu/06f9bf4f-f939-43ee-b9e4-1541b3d4adc2
# [(0, 0.8966808319091797), (1, 0.6501817107200623), (0, 0.7329882383346558), (0, 0.9528799653053284), (0, 0.9205692410469055), (0, 0.897779107093811), (0, 0.9252799153327942), (0, 0.9190554618835449), (0, 0.9222333431243896), (0, 0.8937707543373108)]
# =======================
# /home/sentic/storage2/iccv_test_madu/03778902-0865-4bca-a346-4e1b1aeb4be6
# [(1, 0.5500963926315308), (0, 0.7661909461021423), (0, 0.7881520390510559), (0, 0.8961915969848633), (0, 0.8920049667358398), (0, 0.8823186159133911), (0, 0.8247970938682556), (0, 0.8206191062927246), (0, 0.8552199006080627), (0, 0.9018937945365906)]
# =======================
# /home/sentic/storage2/iccv_test_madu/020fd835-978e-4c56-b108-290806f4de7a
# [(1, 0.5044437646865845), (1, 0.6495214104652405), (1, 0.5323262810707092), (0, 0.8834145665168762), (0, 0.8689897060394287), (0, 0.8349105715751648), (0, 0.855484127998352), (0, 0.8513278961181641), (0, 0.8648744821548462), (0, 0.7965900897979736)]
# =======================
# /home/sentic/storage2/iccv_test_madu/05113e57-911e-420a-9f39-0dbd967d0564
# [(0, 0.8121695518493652), (0, 0.7860342860221863), (1, 0.6161471605300903), (0, 0.8960602879524231), (1, 0.8413069248199463), (1, 0.8345297574996948), (0, 0.8436819314956665), (0, 0.8307253122329712), (0, 0.8664000034332275), (1, 0.44571489095687866)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cf676a84-ee30-4ab2-ba41-b1f41198a32d
# [(0, 0.902247965335846), (0, 0.8906986713409424), (0, 0.802727222442627), (1, 0.5809512734413147), (0, 0.8706614375114441), (0, 0.8290209174156189), (0, 0.9341102242469788), (0, 0.9124464988708496), (0, 0.8939812779426575), (0, 0.8984665274620056)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9d3e899d-fbc7-4868-a354-69f55afac83d
# [(0, 0.8623303174972534), (0, 0.848146378993988), (0, 0.7265064120292664), (0, 0.8736528158187866), (1, 0.7903127074241638), (1, 0.8356783986091614), (1, 0.6478919386863708), (1, 0.6909914612770081), (0, 0.79972243309021), (0, 0.8165265917778015)]
# =======================
# /home/sentic/storage2/iccv_test_madu/213d8de7-fc09-4a6d-a661-daa6e2968636
# [(1, 0.6346130967140198), (1, 0.6517057418823242), (1, 0.5893296003341675), (1, 0.627548098564148), (0, 0.7128635048866272), (1, 0.5634194016456604), (0, 0.8329107165336609), (0, 0.8055031299591064), (0, 0.7572391033172607), (0, 0.7804587483406067)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4e5891d1-d186-4d01-8035-f95f13161059
# [(0, 0.8560154438018799), (0, 0.8337696194648743), (0, 0.768491268157959), (0, 0.8198339343070984), (0, 0.762679934501648), (0, 0.7541430592536926), (0, 0.8431656956672668), (0, 0.8243366479873657), (0, 0.6968216896057129), (1, 0.4877367615699768)]
# =======================
# /home/sentic/storage2/iccv_test_madu/78206e36-46be-4995-8f90-20ed7a265866
# [(0, 0.7942625880241394), (1, 0.5153183341026306), (1, 0.46339231729507446), (1, 0.4357009828090668), (0, 0.6993764638900757), (1, 0.3800695538520813), (0, 0.6993286609649658), (0, 0.6955696940422058), (0, 0.8145838975906372), (0, 0.8383818864822388)]
# =======================
# /home/sentic/storage2/iccv_test_madu/09bd56d3-29cd-47fb-bded-a6ad828d8225
# [(0, 0.8866933584213257), (0, 0.8352341055870056), (1, 0.7628133296966553), (0, 0.9813716411590576), (0, 0.9951144456863403), (0, 0.9457653760910034), (0, 0.929396390914917), (0, 0.9188233017921448), (0, 0.9228335618972778), (0, 0.9224116206169128)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9aedd019-d999-4435-b12f-ec02ca448011
# [(0, 0.8144549131393433), (0, 0.7628993391990662), (0, 0.7351006269454956), (1, 0.6418612599372864), (0, 0.7428210973739624), (0, 0.8629269599914551), (0, 0.8528963923454285), (0, 0.8417595028877258), (0, 0.781894326210022), (0, 0.7473278045654297)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3f9ba4ca-380b-4e7f-8667-3b980cd9d5f6
# [(0, 0.8852775692939758), (0, 0.8597593903541565), (0, 0.749643862247467), (0, 0.8841201663017273), (0, 0.9032920002937317), (0, 0.8764192461967468), (0, 0.8944012522697449), (0, 0.8880733847618103), (0, 0.8292632102966309), (1, 0.6540078520774841)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cf03068b-13d4-4423-a30c-8c5e972c9d88
# [(0, 0.9427482485771179), (0, 0.9528610110282898), (0, 0.7832099795341492), (1, 0.5573607683181763), (0, 0.9305819272994995), (0, 0.8741060495376587), (0, 0.90216064453125), (0, 0.8817906975746155), (0, 0.8712763786315918), (0, 0.8631641268730164)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c73a8bbf-de1e-44cf-a6f9-54bf66e61f51
# [(0, 0.8505136966705322), (0, 0.7277804017066956), (0, 0.6832004189491272), (1, 0.556812584400177), (0, 0.8482120633125305), (0, 0.7996160984039307), (1, 0.6371820569038391), (0, 0.7894536256790161), (0, 0.9041544198989868), (1, 0.5426562428474426)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9a3c14d3-2b9e-48cc-9b80-5f31353498c7
# [(0, 0.8110906481742859), (0, 0.8784701228141785), (1, 0.6538581848144531), (0, 0.8993638753890991), (0, 0.9012266993522644), (0, 0.8796253800392151), (0, 0.8576437830924988), (0, 0.8859581351280212), (0, 0.9004666805267334), (0, 0.8210471868515015)]
# =======================
# /home/sentic/storage2/iccv_test_madu/53bb10c1-adfc-4f1d-a05d-4afc98b5ca29
# [(1, 0.6018005013465881), (0, 0.8521338701248169), (0, 0.8349694013595581), (0, 0.8939865231513977), (0, 0.8863779902458191), (0, 0.8605940937995911), (0, 0.8552636504173279), (0, 0.8437942862510681), (0, 0.8481031060218811), (0, 0.8425279855728149)]
# =======================
# /home/sentic/storage2/iccv_test_madu/81b6f310-6369-464e-bfef-4c41fabcc2bb
# [(0, 0.8122051954269409), (1, 0.648034393787384), (0, 0.7625933289527893), (0, 0.8047417402267456), (0, 0.8806313276290894), (0, 0.8530780076980591), (0, 0.862031102180481), (0, 0.8486343622207642), (0, 0.8883875012397766), (0, 0.8799319863319397)]
# =======================
# /home/sentic/storage2/iccv_test_madu/44fb7221-7e5e-47ed-81b4-fbec62aa5d6a
# [(0, 0.7281970977783203), (0, 0.7559919953346252), (1, 0.5540955066680908), (0, 0.9013994336128235), (0, 0.9389634132385254), (0, 0.898654580116272), (0, 0.8819786310195923), (0, 0.8734130263328552), (0, 0.8752317428588867), (0, 0.8744427561759949)]
# =======================
# /home/sentic/storage2/iccv_test_madu/5294a8ee-296d-453e-93bc-e6f10c39772f
# [(1, 0.5452030301094055), (1, 0.49909669160842896), (0, 0.7095298171043396), (0, 0.8192504048347473), (0, 0.7821422815322876), (0, 0.8038647174835205), (0, 0.8895041942596436), (0, 0.8731802701950073), (0, 0.7851331830024719), (0, 0.8502289652824402)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7fc87d51-d6f9-4c69-b67c-8a46e120316f
# [(0, 0.8084340691566467), (0, 0.8506402373313904), (0, 0.7617911696434021), (0, 0.7878376245498657), (0, 0.8710792064666748), (0, 0.8184553980827332), (0, 0.8601829409599304), (0, 0.8370718955993652), (0, 0.7924941182136536), (1, 0.45905840396881104)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8bcc83c1-1b66-47d8-9e6f-c57bb3b96aab
# [(0, 0.8849448561668396), (0, 0.8384547233581543), (1, 0.7450140714645386), (0, 0.9812095761299133), (0, 0.9931941032409668), (0, 0.9452350735664368), (0, 0.9251833558082581), (0, 0.9139677286148071), (0, 0.930992066860199), (0, 0.9302219748497009)]
# =======================
# /home/sentic/storage2/iccv_test_madu/11c0753e-72fc-482d-83ae-48a5badb54b1
# [(0, 0.7128395438194275), (0, 0.7664012908935547), (0, 0.761009693145752), (1, 0.5534759759902954), (1, 0.5067732334136963), (1, 0.5397542119026184), (0, 0.7515770196914673), (0, 0.7419233322143555), (0, 0.8045507073402405), (0, 0.835403323173523)]
# =======================
# /home/sentic/storage2/iccv_test_madu/43ef4d91-f6f8-4357-b348-774a8282ea2b
# [(0, 0.8733448386192322), (0, 0.8529312014579773), (0, 0.8414202332496643), (0, 0.8830034732818604), (0, 0.8697636723518372), (0, 0.8316353559494019), (0, 0.8502320647239685), (0, 0.8393450379371643), (0, 0.7282698154449463), (1, 0.49260127544403076)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bf45771e-8060-44fa-8eba-b017334f940c
# [(0, 0.8377454280853271), (0, 0.8460528254508972), (1, 0.8446409106254578), (0, 0.9866472482681274), (0, 0.9920936226844788), (0, 0.9399279356002808), (0, 0.9229592680931091), (0, 0.9079669117927551), (0, 0.9267175197601318), (0, 0.936908483505249)]
# =======================
# /home/sentic/storage2/iccv_test_madu/05f703f9-4afd-40b4-b1a6-f94bcbf72747
# [(1, 0.6686475276947021), (1, 0.8032257556915283), (1, 0.5812283158302307), (0, 0.7712265253067017), (0, 0.7895475625991821), (0, 0.8606182336807251), (0, 0.8881294131278992), (0, 0.8788400292396545), (0, 0.8249782919883728), (1, 0.6455734968185425)]
# =======================
# /home/sentic/storage2/iccv_test_madu/16e0ca04-d690-4f16-9494-200b79e6665e
# [(0, 0.765123188495636), (0, 0.7749490737915039), (1, 0.4887809753417969), (0, 0.8738440871238708), (0, 0.7896459698677063), (0, 0.7781729102134705), (1, 0.8630505800247192), (1, 0.9021065831184387), (1, 0.7858464121818542), (1, 0.741865336894989)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a081e46e-00c3-439e-b1d4-920302a7cd45
# [(1, 0.5326583981513977), (1, 0.6057661771774292), (1, 0.50664222240448), (0, 0.9152793884277344), (0, 0.9277985692024231), (0, 0.8634621500968933), (0, 0.8873142004013062), (0, 0.8561139106750488), (0, 0.7986577749252319), (0, 0.8105238080024719)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3bb08e82-c62b-4dc4-b349-44df7e54aaf3
# [(1, 0.5470911860466003), (0, 0.7589355707168579), (0, 0.7780173420906067), (0, 0.8996776342391968), (0, 0.8388851284980774), (0, 0.880837619304657), (0, 0.8999350666999817), (0, 0.8941539525985718), (0, 0.906807541847229), (0, 0.8511452078819275)]
# =======================
# /home/sentic/storage2/iccv_test_madu/51e1ef9a-ae4b-4cba-a32f-bd3ea042b51a
# [(0, 0.802702784538269), (1, 0.4245494604110718), (0, 0.7555281519889832), (0, 0.8312153816223145), (0, 0.8418692350387573), (0, 0.826143205165863), (0, 0.7907532453536987), (0, 0.7749030590057373), (0, 0.7157835960388184), (0, 0.7341645359992981)]
# =======================
# /home/sentic/storage2/iccv_test_madu/11698a87-5e2b-4170-ad27-9a16dfd6071a
# [(0, 0.8792986869812012), (0, 0.8584764003753662), (0, 0.8436222672462463), (0, 0.874578058719635), (0, 0.8480119705200195), (0, 0.8188039660453796), (0, 0.8425437211990356), (0, 0.8290265798568726), (1, 0.5700045228004456), (1, 0.6531909704208374)]
# =======================
# /home/sentic/storage2/iccv_test_madu/67ea7640-8208-4c3a-a761-8291c2bc3893
# [(0, 0.7799729108810425), (0, 0.7575147151947021), (1, 0.5060986280441284), (0, 0.7642728090286255), (0, 0.7625435590744019), (0, 0.8371915221214294), (0, 0.780244767665863), (0, 0.7785958647727966), (0, 0.8635439276695251), (0, 0.7928333282470703)]
# =======================
# /home/sentic/storage2/iccv_test_madu/0bf9507c-8e08-488a-ba41-a9260598747a
# [(0, 0.71542888879776), (0, 0.7750478982925415), (1, 0.596791684627533), (0, 0.8427489995956421), (0, 0.7364080548286438), (1, 0.4465402066707611), (0, 0.7860469818115234), (0, 0.7858592867851257), (0, 0.8565704226493835), (0, 0.8462211489677429)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4ecddce0-b5ad-44d5-ab6b-66d99b592d67
# [(0, 0.9210990071296692), (0, 0.9209908843040466), (0, 0.7302677035331726), (0, 0.8523070812225342), (0, 0.9238849878311157), (0, 0.8796350359916687), (0, 0.9089465737342834), (0, 0.8981543183326721), (0, 0.7224547266960144), (1, 0.7689375877380371)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c78643e4-7f80-4cfc-aadd-257b5ec55d87
# ...
# [(0, 0.7495754361152649), (0, 0.7574119567871094), (1, 0.5052146315574646), (0, 0.7867487072944641), (0, 0.7702820301055908), (0, 0.838798999786377), (0, 0.7310131788253784), (0, 0.7845962643623352), (0, 0.8302971124649048), (0, 0.7762249112129211)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9fdea562-e2fd-49de-a997-482cbfb31d79
# [(1, 0.7311568856239319), (1, 0.8094592094421387), (0, 0.6957630515098572), (0, 0.8951123356819153), (0, 0.7645252346992493), (0, 0.8430159687995911), (0, 0.8606911301612854), (0, 0.8651335835456848), (0, 0.7883034944534302), (0, 0.7736268639564514)]
# =======================
# /home/sentic/storage2/iccv_test_madu/92464661-c296-4bb8-89a5-38d9dcf93da6
# [(0, 0.897532045841217), (0, 0.8770162463188171), (0, 0.7803125977516174), (1, 0.5010619759559631), (0, 0.9018263220787048), (0, 0.8819181323051453), (0, 0.9017742276191711), (0, 0.871172308921814), (0, 0.9024304151535034), (0, 0.8956902623176575)]
# =======================
# /home/sentic/storage2/iccv_test_madu/461bdbdc-df07-4a58-9baf-17b79c2ca978
# [(1, 0.5128991603851318), (1, 0.42046448588371277), (0, 0.7009449005126953), (1, 0.5321827530860901), (0, 0.7805207967758179), (1, 0.3398027718067169), (0, 0.7858483195304871), (0, 0.751248300075531), (0, 0.6505884528160095), (1, 0.3851276636123657)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9135229f-3882-4052-ba7a-9c989f58a5b5
# [(0, 0.8964222073554993), (0, 0.9244624376296997), (0, 0.9236568212509155), (0, 0.8720229864120483), (0, 0.7723609805107117), (1, 0.5768186450004578), (0, 0.8212504982948303), (0, 0.7969264388084412), (0, 0.9134604930877686), (0, 0.8946802616119385)]
# =======================
# /home/sentic/storage2/iccv_test_madu/aa8c8301-0e0a-4b09-bb10-4999be8033c8
# [(0, 0.9759249687194824), (0, 0.973716676235199), (0, 0.776065468788147), (1, 0.5779797434806824), (0, 0.970753014087677), (0, 0.9111538529396057), (0, 0.9117398262023926), (0, 0.9148865938186646), (0, 0.9108996391296387), (0, 0.8961443901062012)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c76af05f-2f20-435f-9cb0-a7d933e9f7e9
# [(0, 0.6759872436523438), (1, 0.8151420950889587), (0, 0.6929555535316467), (0, 0.90381920337677), (0, 0.8904722332954407), (0, 0.8675644993782043), (0, 0.8259685635566711), (0, 0.8137186765670776), (0, 0.7428547739982605), (0, 0.7512841820716858)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3e67037b-291c-4650-a815-6214367f500d
# [(0, 0.7508396506309509), (1, 0.4642137289047241), (0, 0.8292418718338013), (0, 0.9105868935585022), (0, 0.9092884659767151), (0, 0.8821403980255127), (0, 0.8800196647644043), (0, 0.8763180375099182), (0, 0.9113234877586365), (0, 0.9079139232635498)]
# =======================
# /home/sentic/storage2/iccv_test_madu/33fa87c5-fb96-40a4-8fb6-957f8110502d
# [(1, 0.5927891731262207), (1, 0.5339228510856628), (1, 0.6359955072402954), (0, 0.7633436918258667), (0, 0.8603421449661255), (0, 0.8293748497962952), (0, 0.798018753528595), (0, 0.7882905602455139), (0, 0.8044880628585815), (0, 0.8279435634613037)]
# =======================
# /home/sentic/storage2/iccv_test_madu/38f3dc89-d531-4c98-aa69-d0a4087096ef
# [(0, 0.7206791639328003), (0, 0.7692089080810547), (0, 0.7715495824813843), (1, 0.5615697503089905), (0, 0.7546319365501404), (1, 0.49263131618499756), (0, 0.7611480355262756), (0, 0.7496098279953003), (0, 0.8155978322029114), (0, 0.8456652164459229)]
# =======================
# /home/sentic/storage2/iccv_test_madu/34ba43a4-4631-4911-80ab-5ce94b899693
# [(0, 0.7723104953765869), (1, 0.7027711272239685), (1, 0.6506538987159729), (0, 0.9502411484718323), (0, 0.9143210649490356), (0, 0.8758699893951416), (0, 0.9304347634315491), (0, 0.9000858068466187), (0, 0.8982481360435486), (0, 0.8841268420219421)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2b2ef72c-adcc-4a7e-b9f2-a5178f72eb7b
# [(1, 0.44238680601119995), (1, 0.5985303521156311), (1, 0.6376898884773254), (0, 0.8804376125335693), (0, 0.872308611869812), (0, 0.8648764491081238), (0, 0.7049620151519775), (0, 0.7200573086738586), (1, 0.7445312142372131), (1, 0.7228176593780518)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7caa361a-a68e-41cf-ba59-af404bcac5b7
# [(0, 0.9060509204864502), (0, 0.9026191234588623), (0, 0.7634684443473816), (0, 0.8485618233680725), (0, 0.8944425582885742), (0, 0.8626542687416077), (0, 0.8739745020866394), (0, 0.8617919683456421), (0, 0.7747808694839478), (1, 0.5277417302131653)]
# =======================
# /home/sentic/storage2/iccv_test_madu/2bee4e34-9502-44a9-b2ea-d5709cbf935b
# [(0, 0.8307094573974609), (0, 0.804025411605835), (0, 0.7665987014770508), (1, 0.6732650399208069), (0, 0.8299089074134827), (0, 0.8079739212989807), (0, 0.9062419533729553), (0, 0.8954865336418152), (0, 0.8225669860839844), (0, 0.9080573916435242)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6fd24efe-f69a-4d39-b7c2-b2220cab2ffb
# [(0, 0.7123545408248901), (0, 0.7009079456329346), (1, 0.5606157183647156), (1, 0.5307358503341675), (0, 0.7165224552154541), (1, 0.54694664478302), (0, 0.6771125793457031), (0, 0.660967230796814), (0, 0.727992594242096), (0, 0.7372704148292542)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b98f2576-535e-466c-a845-65b919b29564
# [(0, 0.8680008053779602), (0, 0.8735684752464294), (0, 0.7968700528144836), (1, 0.7578527331352234), (0, 0.9153445959091187), (0, 0.8909047842025757), (0, 0.9146170616149902), (0, 0.9043172001838684), (0, 0.9136900305747986), (0, 0.9189792275428772)]
# =======================
# /home/sentic/storage2/iccv_test_madu/1ae5582e-50ac-4d80-818b-c56c02e9901a
# [(0, 0.8132912516593933), (0, 0.8180267810821533), (0, 0.7303734421730042), (1, 0.5606667399406433), (0, 0.7447545528411865), (0, 0.7535337805747986), (0, 0.7167771458625793), (0, 0.707680344581604), (0, 0.7762606739997864), (1, 0.45199233293533325)]
# =======================
# /home/sentic/storage2/iccv_test_madu/b9729429-6718-43c3-bc28-8a7bbdefdc59
# [(0, 0.858501672744751), (0, 0.8553542494773865), (1, 0.615182101726532), (0, 0.8836085796356201), (0, 0.8842429518699646), (0, 0.8617663979530334), (0, 0.9085619449615479), (0, 0.9057949781417847), (0, 0.8166238069534302), (0, 0.8280104398727417)]
# =======================
# /home/sentic/storage2/iccv_test_madu/036bd050-bd21-4108-9587-1379bb7a23eb
# [(1, 0.7603377103805542), (1, 0.7963352799415588), (1, 0.7496726512908936), (0, 0.8391585946083069), (0, 0.845000684261322), (0, 0.8702617883682251), (0, 0.7780774235725403), (0, 0.7358590960502625), (0, 0.7720826268196106), (1, 0.6433508396148682)]
# =======================
# /home/sentic/storage2/iccv_test_madu/9669d158-bc47-4327-84ad-368d40db9832
# [(0, 0.9611691832542419), (0, 0.9720526337623596), (0, 0.8643227219581604), (0, 0.7749819755554199), (0, 0.7602885365486145), (1, 0.42451560497283936), (0, 0.7087499499320984), (0, 0.6850133538246155), (0, 0.9009658098220825), (0, 0.8914785385131836)]
# =======================
# /home/sentic/storage2/iccv_test_madu/904293c1-9945-41c1-bb92-1424f64e900b
# [(0, 0.7730717062950134), (1, 0.5302708745002747), (0, 0.704176127910614), (0, 0.8881707787513733), (0, 0.8774991035461426), (0, 0.8578183054924011), (0, 0.877363383769989), (0, 0.8743605613708496), (0, 0.8667958378791809), (0, 0.8679761290550232)]
# =======================
# /home/sentic/storage2/iccv_test_madu/57c066df-9a2f-412e-8ee3-bb4f1ac4aadd
# [(0, 0.8935325741767883), (0, 0.874577522277832), (0, 0.8088740706443787), (1, 0.55110764503479), (0, 0.9142873287200928), (0, 0.8869829177856445), (0, 0.921441912651062), (0, 0.9141127467155457), (0, 0.9131760597229004), (0, 0.9115544557571411)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4f693909-fb91-4542-9495-79b6cfd92197
# [(0, 0.7600655555725098), (1, 0.4563807547092438), (0, 0.8075432777404785), (0, 0.940759003162384), (0, 0.8849812150001526), (0, 0.8142826557159424), (0, 0.864888072013855), (0, 0.8520969152450562), (0, 0.9166412949562073), (0, 0.9308809638023376)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8f58c3bd-9bdc-4fb4-9590-c2433744ad93
# [(0, 0.9082272052764893), (0, 0.8846996426582336), (0, 0.9168826341629028), (0, 0.8668689131736755), (0, 0.7907646894454956), (1, 0.43418198823928833), (0, 0.8490294814109802), (0, 0.8235694169998169), (0, 0.9120766520500183), (0, 0.8984450697898865)]
# =======================
# /home/sentic/storage2/iccv_test_madu/624237b4-746a-4138-bfa3-ae517c727faa
# [(1, 0.5291118621826172), (1, 0.5210086703300476), (0, 0.7161449790000916), (0, 0.867861807346344), (0, 0.7897319197654724), (0, 0.8126230835914612), (0, 0.8628425002098083), (0, 0.861553966999054), (0, 0.7349525094032288), (0, 0.7889089584350586)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a3fa7138-b41c-4ec9-a3f6-a9fa50724c4d
# [(0, 0.8681696057319641), (1, 0.6538487672805786), (1, 0.7540744543075562), (0, 0.7936661243438721), (1, 0.6567347645759583), (0, 0.7843007445335388), (0, 0.8665088415145874), (0, 0.8540691137313843), (0, 0.8526841998100281), (0, 0.9130555987358093)]
# =======================
# /home/sentic/storage2/iccv_test_madu/d8a9d1f5-8914-4c7a-ae3b-9f630fe2ce55
# [(0, 0.7924219369888306), (0, 0.8189494609832764), (1, 0.5708374381065369), (0, 0.7717812061309814), (0, 0.8616155385971069), (0, 0.8722328543663025), (0, 0.835030198097229), (0, 0.8085386753082275), (0, 0.8897508382797241), (0, 0.8571983575820923)]
# =======================
# /home/sentic/storage2/iccv_test_madu/12578b3b-55f1-4aff-a4bd-1dd21b2b3b16
# [(0, 0.9263742566108704), (0, 0.9187272191047668), (0, 0.9009268879890442), (1, 0.4367278516292572), (0, 0.9316352009773254), (0, 0.9043492674827576), (0, 0.9310026168823242), (0, 0.9241282939910889), (0, 0.7484648823738098), (0, 0.7629992961883545)]
# =======================
# /home/sentic/storage2/iccv_test_madu/4c4cd649-d67c-4f1d-b473-f00fc1ab603c
# [(0, 0.7177989482879639), (0, 0.7715997099876404), (0, 0.719561755657196), (1, 0.5890939235687256), (0, 0.7855979800224304), (1, 0.5096246600151062), (0, 0.757469654083252), (0, 0.7494105696678162), (0, 0.7885374426841736), (0, 0.8425929546356201)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bec2b236-c289-4bd9-9164-04faaf6f8ced
# [(0, 0.7087782025337219), (0, 0.7075175046920776), (0, 0.6889913082122803), (0, 0.7279874682426453), (0, 0.8000510334968567), (0, 0.7749374508857727), (0, 0.7896690964698792), (0, 0.7945659160614014), (1, 0.7919445633888245), (1, 0.8172531723976135)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6ee88c0e-5a0f-4a96-a885-32cc7315cd00
# [(0, 0.94271320104599), (0, 0.9442214965820312), (0, 0.9033620357513428), (0, 0.9459248185157776), (0, 0.9452756643295288), (0, 0.889804482460022), (0, 0.9369654655456543), (0, 0.9245178699493408), (0, 0.739996612071991), (1, 0.4784952402114868)]
# =======================
# /home/sentic/storage2/iccv_test_madu/a4358a78-a495-4dc5-9d41-48576982313a
# [(0, 0.8988312482833862), (0, 0.8875966668128967), (0, 0.8953856825828552), (0, 0.8920354843139648), (0, 0.872919499874115), (0, 0.8501710295677185), (0, 0.8738846182823181), (0, 0.8597549796104431), (1, 0.5512135624885559), (1, 0.6259481310844421)]
# =======================
# /home/sentic/storage2/iccv_test_madu/6949c8bb-6aa4-4da2-8c72-aadc61712c4e
# [(0, 0.8935832977294922), (0, 0.8824942111968994), (1, 0.6321801543235779), (0, 0.7693182826042175), (0, 0.8597151041030884), (0, 0.819238007068634), (1, 0.646351158618927), (1, 0.6940487623214722), (0, 0.8225919008255005), (0, 0.8303006291389465)]
# =======================
# /home/sentic/storage2/iccv_test_madu/29d0cba1-c5e4-421c-8fb1-84d60540d209
# [(0, 0.9524440169334412), (0, 0.9477275013923645), (1, 0.5825026631355286), (0, 0.8840838074684143), (0, 0.8917509913444519), (0, 0.8419599533081055), (1, 0.6428206562995911), (0, 0.6009384393692017), (0, 0.7327032089233398), (1, 0.7232981324195862)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8a623e4f-9e53-4e1f-8cfa-0d3d9aab41a8
# [(0, 0.8660029768943787), (0, 0.8358471393585205), (0, 0.7883245348930359), (0, 0.8659659624099731), (0, 0.809688925743103), (0, 0.7787597179412842), (0, 0.7851710319519043), (0, 0.7410447001457214), (1, 0.8832235932350159), (1, 0.8526285290718079)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cef6396d-5238-4612-a8c3-242f427866a6
# [(0, 0.82501220703125), (0, 0.6802303791046143), (1, 0.605305552482605), (1, 0.581103503704071), (0, 0.6855315566062927), (0, 0.7769926190376282), (0, 0.7122562527656555), (0, 0.7366617918014526), (1, 0.4885157644748688), (1, 0.5455504655838013)]
# =======================
# /home/sentic/storage2/iccv_test_madu/cd07573b-868d-49c2-882a-802038c99084
# [(1, 0.6464359164237976), (1, 0.6858527064323425), (0, 0.7083079218864441), (0, 0.8031295537948608), (0, 0.8657596707344055), (0, 0.796989917755127), (0, 0.765628457069397), (0, 0.7731016874313354), (1, 0.606937050819397), (1, 0.63103848695755)]
# =======================
# /home/sentic/storage2/iccv_test_madu/862f999b-dcf6-48d9-8954-bcaf792223b6
# [(0, 0.916538655757904), (0, 0.9048301577568054), (0, 0.772611141204834), (1, 0.7916209101676941), (0, 0.8633608818054199), (1, 0.43960270285606384), (0, 0.8698543906211853), (0, 0.8575437664985657), (0, 0.8462015986442566), (0, 0.8642807006835938)]
# =======================
# /home/sentic/storage2/iccv_test_madu/762b3f3b-bad2-428a-89a3-d097cef21d55
# [(0, 0.9439339637756348), (0, 0.9380580186843872), (0, 0.9076457619667053), (0, 0.9617131948471069), (0, 0.9547752141952515), (0, 0.9087514281272888), (0, 0.9328429698944092), (0, 0.9182141423225403), (0, 0.7532761096954346), (1, 0.49404048919677734)]
# =======================
# /home/sentic/storage2/iccv_test_madu/7d5b60cb-39c7-4a16-9793-46df6e9f9ffe
# [(1, 0.6839026808738708), (1, 0.6801565289497375), (1, 0.6438856720924377), (0, 0.9096087217330933), (0, 0.9016149044036865), (0, 0.8546584844589233), (0, 0.6625797152519226), (0, 0.6457513570785522), (0, 0.8119269609451294), (0, 0.7888695001602173)]
# =======================
# /home/sentic/storage2/iccv_test_madu/8eca3f70-6fb2-4e40-8be6-c34ff23ec375
# [(0, 0.7917753458023071), (0, 0.8323906064033508), (0, 0.7553421854972839), (0, 0.8409126400947571), (0, 0.7809176445007324), (0, 0.7934116125106812), (0, 0.6312366724014282), (1, 0.5358700752258301), (1, 0.5022626519203186), (1, 0.47185927629470825)]
# =======================
# /home/sentic/storage2/iccv_test_madu/3d91da1d-960e-4172-a1a3-4fdc741ef1a7
# [(1, 0.5675419569015503), (1, 0.5294734239578247), (1, 0.5783202648162842), (0, 0.7725662589073181), (0, 0.794483482837677), (0, 0.7883358597755432), (0, 0.7466914057731628), (0, 0.7143052220344543), (0, 0.7570163011550903), (1, 0.5103880167007446)]
# =======================
# /home/sentic/storage2/iccv_test_madu/17d50780-48b2-444e-9961-611d2c5fb65e
# [(0, 0.868805468082428), (0, 0.852702796459198), (0, 0.8507000207901001), (0, 0.8844255208969116), (0, 0.8833726048469543), (0, 0.8329166769981384), (0, 0.8668252825737), (0, 0.8511199951171875), (0, 0.7075883150100708), (1, 0.47814133763313293)]
# =======================
# /home/sentic/storage2/iccv_test_madu/c0a6555b-3174-49e2-8419-ce9fe60c5f38
# [(0, 0.7601107358932495), (0, 0.741391122341156), (0, 0.7680490612983704), (0, 0.8335480690002441), (0, 0.7831742763519287), (0, 0.7781108021736145), (0, 0.7533561587333679), (0, 0.7466267347335815), (0, 0.7694892883300781), (1, 0.44091925024986267)]
# =======================
# /home/sentic/storage2/iccv_test_madu/bfde7588-72cc-4cbf-bc88-6bfcb0f439d1
# [(0, 0.8932920098304749), (0, 0.8946309089660645), (0, 0.7672978043556213), (1, 0.7056092619895935), (0, 0.9265817999839783), (0, 0.9069203734397888), (0, 0.8874675035476685), (0, 0.8760198354721069), (0, 0.926563560962677), (0, 0.9377766251564026)]
# =======================
# /home/sentic/storage2/iccv_test_madu/61656d82-dbdb-473b-a575-5b67085b7f40
# [(0, 0.8835875391960144), (0, 0.8561621904373169), (0, 0.7136833071708679), (0, 0.8947160243988037), (0, 0.8845769762992859), (0, 0.8716000318527222), (0, 0.8919620513916016), (0, 0.8853134512901306), (0, 0.8080398440361023), (1, 0.7370113134384155)]
# =======================

# %%
counter
# Out:
# 775

# %%
len(covid_fnames)
# Out:
# 542
