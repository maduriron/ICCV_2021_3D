# %%
from utilities_scripts import RandAugment

# %%
r = RandAugment(n=2, m = 9)

# %%
lx = r.augment_list

# %%
from PIL import Image
# ELIMINATE 
# 0, 1, 2, 4, 5, 6
# KEEP
# 3, 7, 8, 9, 10, 11
ix = 12
func, p1, p2 = lx[ix]
m = 15
val = (float(m) / 30) * float(p2 - p1) + p1
print(func)
print(val)
# Out:
# <function ShearY at 0x7f16466006a8>
# 0.15

# %%
path = "/home/sentic/Documents/data/storage2/LEUKEMIA/C-NMC_Leukemia/C-NMC_training_data/fold_0/all/UID_14_17_3_all.bmp"

func(Image.open(path), val)
# Out:
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7F13A47CC7B8>

# %%
Image.open(path)
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=450x450 at 0x7F13A47CC400>
